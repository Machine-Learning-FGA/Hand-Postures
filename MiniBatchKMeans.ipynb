# %%
import pandas as pd

dataset = pd.read_csv('allUsersCompleto.csv')
dataset = dataset.drop(0)
dataset.head()
# Out:
#    Class  User         X0         Y0         Z0         X1         Y1  \
# 1      1     0  56.527558  72.266609 -61.935252  39.135978  82.538530
# 2      1     0  55.849928  72.469064 -62.562788  37.988804  82.631347
# 3      1     0  55.329647  71.707275 -63.688956  36.561863  81.868749
# 4      1     0  55.142401  71.435607 -64.177303  36.175818  81.556874
# 5      1     0  55.581184  71.641201 -63.703137  34.850565  81.352041
#
#           Z1         X2         Y2    ...             Z8         X9  \
# 1 -49.596509  79.223743  43.254091    ...     -68.827418  61.587452
# 2 -50.606259  78.451526  43.567403    ...     -68.889316  61.686427
# 3 -52.752784  86.320630  68.214645    ...     -72.015146  77.387225
# 4 -53.475747  76.986143  42.426849    ...     -69.279906  61.275402
# 5 -54.747443  77.078512  42.548245    ...     -68.853752  61.856847
#
#           Y9         Z9        X10        Y10        Z10        X11  \
# 1  11.779919 -68.827418  61.587452  11.779919 -68.827418  61.587452
# 2  11.793440 -68.889316  61.686427  11.793440 -68.889316  61.686427
# 3  42.717833 -72.015146  77.387225  42.717833 -72.015146  77.387225
# 4  10.841109 -69.279906  61.275402  10.841109 -69.279906  61.275402
# 5  10.851973 -68.853752  61.856847  10.851973 -68.853752  61.856847
#
#          Y11        Z11
# 1  11.779919 -68.827418
# 2  11.793440 -68.889316
# 3  42.717833 -72.015146
# 4  10.841109 -69.279906
# 5  10.851973 -68.853752
#
# [5 rows x 38 columns]

# %%
dataset.describe()
# Out:
#               Class          User            X0            Y0            Z0  \
# count  78094.000000  78094.000000  78094.000000  78094.000000  78094.000000
# mean       2.983802      7.959331     50.346258     85.813333    -29.984650
# std        1.421144      4.697698     32.696092     40.203672     34.361965
# min        1.000000      0.000000   -108.552738    -98.233756   -126.770872
# 25%        2.000000      5.000000     29.295106     63.496517    -56.356229
# 50%        3.000000      9.000000     54.620334     86.526389    -30.864125
# 75%        4.000000     12.000000     72.488981    113.109991     -1.419251
# max        5.000000     14.000000    190.017835    169.175464    113.345119
#
#                  X1            Y1            Z1            X2            Y2  \
# count  78094.000000  78094.000000  78094.000000  78094.000000  78094.000000
# mean      49.595494     86.194311    -29.509025     48.612897     83.772414
# std       32.478022     40.452253     34.764338     33.605342     41.022972
# min     -111.685241    -96.142589   -166.006838   -106.886524   -100.789312
# 25%       28.755437     64.158451    -57.359293     25.171732     58.053214
# 50%       54.215514     87.543634    -30.184005     53.814647     86.460876
# 75%       71.760842    116.238363     -0.367849     71.562025    106.662613
# max      188.691997    170.209350    104.697852    188.760168    168.186466
#
#            ...                 Z8            X9            Y9            Z9  \
# count      ...       78094.000000  78094.000000  78094.000000  78094.000000
# mean       ...         -37.403548     49.582619     69.073013    -38.619534
# std        ...          35.032581     35.661490     41.800059     34.407686
# min        ...        -151.838668   -120.657868    -97.468548   -151.838668
# 25%        ...         -62.980318     23.343734     36.536370    -63.094788
# 50%        ...         -42.454388     56.064020     74.547410    -43.846526
# 75%        ...         -14.447768     74.905085     96.763086    -17.821774
# max        ...         119.213101    189.221529    167.942588    123.380512
#
#                 X10           Y10           Z10           X11           Y11  \
# count  78094.000000  78094.000000  78094.000000  78094.000000  78094.000000
# mean      49.752288     68.084681    -39.096982     49.748965     68.090187
# std       35.885453     41.495634     34.374340     35.893515     41.485034
# min     -120.657868    -97.468548   -151.838668   -120.657868    -97.468548
# 25%       23.097303     35.993766    -63.184896     23.087443     36.017603
# 50%       56.257263     73.807679    -44.321963     56.257751     73.806536
# 75%       74.961845     95.772417    -19.017502     74.962822     95.772838
# max      189.221529    168.352478    123.380512    189.221529    168.352478
#
#                 Z11
# count  78094.000000
# mean     -39.096000
# std       34.375446
# min     -151.838668
# 25%      -63.184896
# 50%      -44.321963
# 75%      -19.017866
# max      123.380512
#
# [8 rows x 38 columns]

# %%
dataset.tail()
# Out:
#        Class  User         X0          Y0         Z0         X1          Y1  \
# 78090      5    14  54.251127  129.177414 -44.252511  27.720784  107.810661
# 78091      5    14  54.334883  129.253842 -44.016320  27.767911  107.914808
# 78092      5    14  54.151540  129.269502 -44.173273  27.725978  108.034006
# 78093      5    14  27.915311  108.007390  10.814957  -0.910435  122.464093
# 78094      5    14  27.898705  108.092877  11.107857 -30.031402   77.740235
#
#               Z1         X2          Y2    ...             Z8         X9  \
# 78090  11.099282  -1.270139  122.758679    ...      -6.543115  87.733364
# 78091  11.069842 -30.334054   77.858214    ...     -62.130563  78.229847
# 78092  11.020347 -22.574718  104.222208    ...       3.835904  78.591554
# 78093 -47.271248 -30.084588   77.705861    ...     -63.221626  88.465709
# 78094 -17.453099  -1.091566  122.827638    ...     -63.026574  78.879653
#
#               Y9         Z9        X10        Y10        Z10        X11  \
# 78090  61.216363 -62.126278  87.733364  61.216363 -62.126278  87.733364
# 78091  33.078407 -45.249543  78.229847  33.078407 -45.249543  78.229847
# 78092  32.327738 -46.166556  78.591554  32.327738 -46.166556  78.591554
# 78093  60.050791 -63.221626  88.465709  60.050791 -63.221626  88.465709
# 78094  31.603100 -47.013736  78.879653  31.603100 -47.013736  78.879653
#
#              Y11        Z11
# 78090  61.216363 -62.126278
# 78091  33.078407 -45.249543
# 78092  32.327738 -46.166556
# 78093  60.050791 -63.221626
# 78094  31.603100 -47.013736
#
# [5 rows x 38 columns]

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
#print(new_dataset.isin(['?']).sum())
#new_dataset = new_dataset.convert_objects(convert_numeric=True)
correlation = dataset.corr()
plt.figure(figsize=(17,15))
g = sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='RdYlGn',xticklabels=True,yticklabels=True)

g.set_yticklabels(g.get_yticklabels(), rotation =0)
g.set_xticklabels(g.get_yticklabels(), size=7, rotation =90)
plt.title('Correlation between different features')
plt.show()

# %%
X = dataset.iloc[:, 1:]
y = dataset.iloc[:, 0]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

def treina_classificador(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    knn = KNeighborsClassifier(n_neighbors=3)
    #knn = DecisionTreeClassifier()
    knn.fit(X_train, y_train)
    print(knn.score(X_train, y_train))
    print(knn.score(X_test, y_test))

# %%
from sklearn.pipeline import make_pipeline
from sklearn.cluster import MiniBatchKMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, NMF, TruncatedSVD
from sklearn.preprocessing import Normalizer, MaxAbsScaler 

ks = [1,2,3,4,5,6,7,8]
pca = PCA(n_components=2)
scaler = MaxAbsScaler()
svd = TruncatedSVD(n_components=36)

inertias = []
results = []
for i in ks:
    model = MiniBatchKMeans(n_clusters=i)
    pipeline = make_pipeline(scaler, pca, model)
    pipeline.fit_transform(X)
    labels = pipeline.predict(X)
    results.append((model, labels))
    inertias.append(model.inertia_)

# %%
# Plot ks vs inertias
plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.show()

# %% [markdown]
# ## 4 Clusters

# %%
BEST_VALUE = 4
labels = results[BEST_VALUE - 1][1]
modelx = results[BEST_VALUE - 1][0]
df = pd.DataFrame({'labels': labels, 'classes': y})
ct = pd.crosstab(df['labels'], df['classes'])
print(ct)
# Out:
# classes     1     2     3     4     5
# labels
# 0        7516   331  5182  4407  5002
# 1         856  8006  1688  2656  4350
# 2        7180    42  6516  4832   524
# 3         712  6599  2958  2880  5857

# %%
from sklearn.metrics import homogeneity_score, silhouette_score, adjusted_rand_score, calinski_harabaz_score
def printresults(y, labels, modelx):
    print('Homogeneity score: {}'.format(homogeneity_score(y, labels)))
    print('Adjusted random score: {}'.format(adjusted_rand_score(y, labels)))
    print('Inertia: {}'.format(modelx.inertia_))
    print('Calinski: {}'.format(calinski_harabaz_score(X, labels)))
    
printresults(y, labels1, modelx)
# Out:
# Homogeneity score: 0.15809413148535348
# Adjusted random score: 0.11806794262920421
# Inertia: 13891.023816666822
# Calinski: 10858.656331742433

# %%
model_plot = results[BEST_VALUE - 1][0]
centroids = model_plot.cluster_centers_

# Assign the columns of centroids: centroids_x, centroids_y
centroids_x = centroids[:,0]
centroids_y = centroids[:,1]

fig1, ax1 = plt.subplots()
# Make a scatter plot of centroids_x and centroids_y
ax1.scatter(centroids_x, centroids_y, marker='D', s=50, c=list(set(labels)))
for i, txt in enumerate(list(set(labels))):
    ax1.annotate(txt, (centroids_x[i],centroids_y[i]))
plt.show()

# %%
from sklearn.manifold import TSNE

def plot_clusters(labels):
    l = []
    dic = {}
    for i in set(labels):
        dic[i] = dic.get(i, 0)
    for i in range(len(labels)):
        if dic[labels[i]] < 2000:
            l += [X.iloc[i, :] + labels[i]]
            #l[i].append(labels[i])
            #l[i] = np.array(l[i], dtype=np.float64)
            dic[labels[i]] = dic.get(labels[i], 0) + 1
    #l = np.array(l, dtype=np.float64)
    print(len(l))
    print(dic)
    model2 = TSNE(learning_rate=200)
    tsne_features = model.fit_transform(l)
    xs = tsne_features[:, 0]
    ys = tsne_features[:, 1]
    plt.scatter(xs, ys, c=np.array(l)[:, -1])
    plt.show()
plot_clusters(labels)
# Out:
# 8000
# {0: 2000, 1: 2000, 2: 2000, 3: 2000}

# %%
treina_classificador(X, labels)
# Out:
# 0.97526852949
# 0.948587614465

# %% [markdown]
# ## 5 Clusters

# %%
BEST_VALUE = 5
labels = results[BEST_VALUE - 1][1]
modelx = results[BEST_VALUE - 1][0]

df = pd.DataFrame({'labels': labels, 'classes': y})
ct = pd.crosstab(df['labels'], df['classes'])
print(ct)
# Out:
# classes     1     2     3     4     5
# labels
# 0        7836    37  1838   944   491
# 1         656  6027  2594  2658  4657
# 2         872  8276  1493  2081  4212
# 3        4173   600  5097  4102  6058
# 4        2727    38  5322  4990   315

# %%
printresults(y, labels, modelx)
# Out:
# Homogeneity score: 0.19370449747023594
# Adjusted random score: 0.13720319284868626
# Inertia: 12013.146158471665
# Calinski: 8783.156661458823

# %%
model_plot = results[BEST_VALUE - 1][0]
centroids = model_plot.cluster_centers_

# Assign the columns of centroids: centroids_x, centroids_y
centroids_x = centroids[:,0]
centroids_y = centroids[:,1]

fig1, ax1 = plt.subplots()
# Make a scatter plot of centroids_x and centroids_y
ax1.scatter(centroids_x, centroids_y, marker='D', s=50, c=list(set(labels)))
for i, txt in enumerate(list(set(labels))):
    ax1.annotate(txt, (centroids_x[i],centroids_y[i]))
plt.show()

# %%
plot_clusters(labels)
# Out:
# 8000
# {0: 2000, 1: 2000, 2: 2000, 3: 2000}

# %%
treina_classificador(X, labels)
# Out:
# 0.968579182753
# 0.936481452739
